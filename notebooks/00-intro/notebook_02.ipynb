# %% [markdown]
# # Math III: Calculus for learning and attacking models
#
# **Training** a model is *descending* the gradient of a loss with respect to the **weights**. **Attacking** a model is *ascending* the
# gradient of the same loss with respect to the **input**. Same mathematics, opposite goals. This notebook covers derivatives,
# gradients, the chain rule (backpropagation), and integration (probabilities, expectations and the area under the ROC curve).

# %%
import jax
import jax.numpy as jnp
import numpy as np
import sympy as sp
from matplotlib import pyplot as plt
from scipy import integrate, stats
from sklearn.metrics import roc_auc_score, roc_curve

jax.config.update("jax_enable_x64", True)
plt.rcParams["figure.dpi"] = 100
rng = np.random.default_rng(42)

# %% [markdown]
# ## 1. The derivative: rate of change
#
# $$
# f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}
# $$
#
# Three ways to obtain it: **numerically** (finite differences), **symbolically** (a formula) and by **automatic differentiation**
# (exact, mechanical application of the chain rule to a program: what JAX, Keras and PyTorch do).

# %%
def sigmoid(x):
    return 1 / (1 + jnp.exp(-x))


x0 = 0.7
x_sym = sp.symbols("x")
formula = sp.diff(1 / (1 + sp.exp(-x_sym)), x_sym)
print("symbolic   :", formula, "=", float(formula.subs(x_sym, x0)))
print("autodiff   :", float(jax.grad(sigmoid)(x0)))
s = float(sigmoid(x0))
print("closed form: sigma*(1-sigma) =", s * (1 - s))

# %% [markdown]
# ### Finite differences: truncation vs. round-off
#
# The central difference $\frac{f(x+h)-f(x-h)}{2h}$ has error $O(h^2)$ but subtracts two nearly equal numbers. Shrinking $h$ helps
# until *floating-point round-off* takes over: the same **numerical stability** issue as `exp(log(x))` in the spam notebooks.

# %%
hs = np.logspace(-14, 0, 60)
f = np.sin
exact = np.cos(1.0)
err_fwd = [abs((f(1 + h) - f(1)) / h - exact) for h in hs]
err_ctr = [abs((f(1 + h) - f(1 - h)) / (2 * h) - exact) for h in hs]
fig, ax = plt.subplots(figsize=(6, 3.6))
ax.loglog(hs, err_fwd, label="forward difference")
ax.loglog(hs, err_ctr, label="central difference")
ax.set(xlabel="step h", ylabel="error of d/dx sin(x) at x=1")
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Partial derivatives and the gradient
#
# For $f:\mathbb{R}^n\to\mathbb{R}$ the **gradient** collects the partial derivatives:
# $\nabla f=\big(\partial f/\partial x_1,\dots,\partial f/\partial x_n\big)$. Two facts to remember:
#
# 1. $\nabla f$ points in the direction of **steepest ascent**; $-\nabla f$ in the direction of steepest descent.
# 2. $\nabla f$ is **perpendicular to the level curves** $f=c$.
#
# The directional derivative along a unit vector $\mathbf{u}$ is $\nabla f\cdot\mathbf{u}=\lVert\nabla f\rVert\cos\theta$, maximal
# for $\mathbf{u}=\nabla f/\lVert\nabla f\rVert$.

# %%
def f2(p):
    x, y = p
    return jnp.sin(x) * jnp.cos(y) + 0.1 * (x**2 + y**2)


grad_f2 = jax.grad(f2)
gx, gy = np.meshgrid(np.linspace(-3, 3, 200), np.linspace(-3, 3, 200))
Z = np.array(f2((gx, gy)))
qx, qy = np.meshgrid(np.linspace(-2.7, 2.7, 12), np.linspace(-2.7, 2.7, 12))
G = np.array([[np.array(grad_f2(jnp.array([a, b]))) for a, b in zip(ra, rb)] for ra, rb in zip(qx, qy)])

fig, ax = plt.subplots(figsize=(5.5, 5))
ax.contour(gx, gy, Z, 20, cmap="viridis")
ax.quiver(qx, qy, G[..., 0], G[..., 1], color="r", alpha=0.7)
ax.set(aspect="equal", title="gradient field (red) is perpendicular to the level curves")
plt.tight_layout()
plt.show()

p = jnp.array([1.0, 0.5])
g = np.array(grad_f2(p))
best = g / np.linalg.norm(g)
angles = np.linspace(0, 2 * np.pi, 361)
dirs = np.c_[np.cos(angles), np.sin(angles)]
print("direction of steepest ascent:", best, "-> angle", np.degrees(np.arctan2(best[1], best[0])).round(1), "deg")
print("angle maximising the directional derivative:", np.degrees(angles[np.argmax(dirs @ g)]).round(1), "deg")

# %% [markdown]
# ## 3. The chain rule is backpropagation
#
# For $y=f(g(x))$: $\dfrac{dy}{dx}=f'(g(x))\,g'(x)$. A neural network is a long composition; **backpropagation** applies the chain
# rule from the output backwards, reusing intermediate results. We do it by hand for a tiny network
# $\hat y=\sigma(w_2\tanh(w_1x))$ with the loss $L=(\hat y-y)^2$ and compare with JAX.

# %%
x, y_true = 1.5, 1.0
w1, w2 = 0.8, -0.4

# forward pass, storing intermediates
a = w1 * x
h = np.tanh(a)
z = w2 * h
y_hat = 1 / (1 + np.exp(-z))
L = (y_hat - y_true) ** 2

# backward pass: chain rule, output to input
dL_dyhat = 2 * (y_hat - y_true)
dyhat_dz = y_hat * (1 - y_hat)
dz_dw2, dz_dh = h, w2
dh_da = 1 - h**2
da_dw1 = x
dL_dw2 = dL_dyhat * dyhat_dz * dz_dw2
dL_dw1 = dL_dyhat * dyhat_dz * dz_dh * dh_da * da_dw1
dL_dx = dL_dyhat * dyhat_dz * dz_dh * dh_da * w1  # note: the same chain, ending at the INPUT


def loss(w1, w2, x):
    return (jax.nn.sigmoid(w2 * jnp.tanh(w1 * x)) - y_true) ** 2


print("by hand :", dL_dw1, dL_dw2, dL_dx)
print("jax.grad:", *[float(v) for v in jax.grad(loss, argnums=(0, 1, 2))(w1, w2, x)])

# %% [markdown]
# Look at the last derivative, $\partial L/\partial x$: the *same* backward pass, continued to the input. **Training** uses
# $\partial L/\partial w$; an **evasion attack** uses $\partial L/\partial x$. The next slides and notebook 11 build on this line.
#
# ### The gradient of the logistic loss
#
# For $z=\mathbf{w}\cdot\mathbf{x}+b$, $p=\sigma(z)$ and the cross-entropy loss $J=-[y\log p+(1-y)\log(1-p)]$:
#
# $$
# \frac{\partial J}{\partial\mathbf{w}}=(p-y)\,\mathbf{x},\qquad\frac{\partial J}{\partial b}=p-y,\qquad
# \boxed{\frac{\partial J}{\partial\mathbf{x}}=(p-y)\,\mathbf{w}}
# $$

# %%
def J(w, b, xv, yv):
    z = jnp.dot(w, xv) + b
    return -(yv * jax.nn.log_sigmoid(z) + (1 - yv) * jax.nn.log_sigmoid(-z))


w = jnp.array([1.5, -2.0, 0.5])
b = 0.1
xv = jnp.array([0.3, 0.8, -1.0])
p = float(jax.nn.sigmoid(jnp.dot(w, xv) + b))
gw, gb, gx = jax.grad(J, argnums=(0, 1, 2))(w, b, xv, 1.0)
print("dJ/dx autodiff:", np.array(gx))
print("(p - y) * w   :", (p - 1.0) * np.array(w))

# %% [markdown]
# ## 4. Integration
#
# The definite integral $\int_a^bf(x)\,dx$ is the (signed) **area under the curve**, the limit of Riemann sums. It is the tool to go
# from a *density* to a *probability* and from a *curve* to a *score*.
#
# ### Numerical integration: three ways to compute $\int_0^1e^x\,dx=e-1$

# %%
f = np.exp
a_, b_ = 0.0, 1.0
print(f"{'n':>7}{'left Riemann':>14}{'trapezoid':>12}{'Monte Carlo':>13}")
for n in (10, 100, 1000, 10000):
    xs = np.linspace(a_, b_, n + 1)
    left = np.sum(f(xs[:-1])) * (b_ - a_) / n
    trap = np.trapezoid(f(xs), xs)
    mc = (b_ - a_) * f(rng.uniform(a_, b_, n)).mean()
    print(f"{n:7d}{left:14.5f}{trap:12.6f}{mc:13.4f}")
print("scipy quad :", integrate.quad(f, a_, b_)[0], "  exact:", np.e - 1)

# %% [markdown]
# Errors: left Riemann $O(1/n)$, trapezoid $O(1/n^2)$, **Monte Carlo $O(1/\sqrt n)$ in *any* dimension**. That last property is why
# sampling is used for high-dimensional integrals (expectations over data distributions).
#
# ### Probability and expectation are integrals
#
# $P(a\le X\le b)=\int_a^bp(x)\,dx$, $\;E[X]=\int x\,p(x)\,dx$, and the CDF $F(x)=\int_{-\infty}^xp(t)\,dt$ satisfies $F'=p$ (the
# **fundamental theorem of calculus**).

# %%
mu, sigma = 0.0, 1.0
p_tail = 2 * integrate.quad(stats.norm.pdf, 3, np.inf)[0]
print(f"P(|z|>3): integral {p_tail:.5f}   scipy sf {2 * stats.norm.sf(3):.5f}")
print(
    "E[X] for Exponential(rate 2):",
    integrate.quad(lambda t: t * stats.expon.pdf(t, scale=0.5), 0, np.inf)[0],
    "(exact 0.5)",
)

xs = np.linspace(-4, 4, 4001)
cdf = np.cumsum(stats.norm.pdf(xs)) * (xs[1] - xs[0])
print("max |integral of pdf - CDF|:", np.abs(cdf - stats.norm.cdf(xs)).max())
print("max |d/dx CDF - pdf|       :", np.abs(np.gradient(stats.norm.cdf(xs), xs) - stats.norm.pdf(xs)).max())

# %% [markdown]
# ### The area under the ROC curve is an integral
#
# A detector outputs a score. Sweeping the threshold traces the ROC curve $\mathrm{TPR}(\mathrm{FPR})$, and
# $\mathrm{AUC}=\int_0^1\mathrm{TPR}\,d\mathrm{FPR}$. Equivalent reading: the probability that a random attack scores higher than a
# random benign event.

# %%
neg = rng.normal(0.0, 1.0, 2000)  # benign scores
pos = rng.normal(1.5, 1.0, 300)  # attack scores
scores = np.r_[neg, pos]
labels = np.r_[np.zeros(len(neg)), np.ones(len(pos))]

fpr, tpr, _ = roc_curve(labels, scores)
auc_trapezoid = np.trapezoid(tpr, fpr)
auc_rank = (pos[:, None] > neg[None, :]).mean()  # P(score_attack > score_benign)
print(
    f"AUC: trapezoid {auc_trapezoid:.4f}   rank statistic {auc_rank:.4f}   sklearn {roc_auc_score(labels, scores):.4f}   theory {stats.norm.cdf(1.5 / np.sqrt(2)):.4f}"
)

fig, ax = plt.subplots(figsize=(4.5, 4.2))
ax.fill_between(fpr, tpr, alpha=0.25)
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], "k:")
ax.set(xlabel="false-positive rate", ylabel="true-positive rate", title=f"ROC, AUC = {auc_trapezoid:.3f}")
plt.tight_layout()
plt.show()

# %% [markdown]
# The ROC hides the base rate; at 0.1% prevalence a *high AUC still gives ~90% false alarms* (notebook 00, section 2).
#
# ## Exercises
#
# 1. Verify with `jax.grad` and by hand that $\frac{d}{dx}\tanh x=1-\tanh^2x$.
# 2. Compute the gradient of $f(x,y)=x^2+3y^2$ at $(2,1)$, take one step of size $\eta=0.1$ in the direction of *descent* and check that $f$ decreases. Repeat with $\eta=0.4$: what happens?
# 3. Estimate $\pi$ with Monte Carlo integration of the quarter circle. How many samples for 3 correct digits?
# 4. In section 3 use the gradient $\partial L/\partial x$ to move $x$ by $+0.1\,\mathrm{sign}(\partial L/\partial x)$. Does the loss increase? (This is the FGSM attack in one dimension.)

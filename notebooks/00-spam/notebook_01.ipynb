# %% [markdown]
# # SPAM or HAM

# %% [markdown]
# ## Implementing a proper Classifier
#
# This notebook builds upon the previous one by:
#
# 1. Providing proper text mining processing using NLTK.
# 2. Implementing a class for the classifier.
# 3. Employing a trick to improve numerical stability.
# 3. Evaluating the classifier against a proper SPAM dataset.
#
# ### Numerical stability
#
# Numerical instability is a concept that refers to the propensity of an algorithm or computational
# procedure to produce inaccurate results due to round-off errors, truncation errors, or other computational issues.
#
# These errors may be small initially but can accumulate and escalate in the course of iterations, leading to
# results that are significantly far-off from the expected or precise value.
#
# The previous implemenation had to use a reduce to multiple several likelihood probabilities together.
#
# Due to rounding error the program can produce a bad result.
#
# This is where smoothing can help (by providing a small probability to unseen words).
#
# Furthermore, we can explore other operations to reduce the number of multiplications:
#
# $$ \log ab = \log a + \log b $$
#
# $$ \exp \log x = x$$

# %% [markdown]
# ## Load Libraries
#
# Import NLTK and download the additional data for the tokenizer and lemmatizer.
#
# **Tokenization** is the process of tokenizing or splitting a string, text into a list of tokens.
# One can think of token as parts like a word is a token in a sentence, and a sentence is a token in a paragraph.
#
# **Lemmatization** is the process of grouping together the different inflected forms of a word so they can be analyzed as a single item.
# Lemmatization is similar to stemming but it brings context to the words. So it links words with similar meanings to one word.
#
# Examples of lemmatization:
#
# - rocks : rock
# - corpora : corpus
# - better : good

# %%
# %matplotlib inline
import math
import nltk
import numpy as np
import polars as pl
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /home/mantunes/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/mantunes/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mantunes/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/mantunes/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/mantunes/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Toy Dataset
#
# Same dataset, but in a traditional format.

# %%
dataset_train = [
('send us your password', 'spam'),
('review our website', 'spam'),
('send your password', 'spam'),
('send us your account', 'spam'),
('Your activity report', 'ham'),
('benefits physical activity', 'ham'),
('the importance vows', 'ham'),
]

dataset_test = [
    ('renew your password', 'spam'),
    ('renew your vows', 'spam'),
    ('benefits of our account', 'ham'),
    ('the importance of physical activity', 'ham')
]

print(f'{dataset_train}')
print(f'{dataset_test}')
# Out:
# [('send us your password', 'spam'), ('review our website', 'spam'), ('send your password', 'spam'), ('send us your account', 'spam'), ('Your activity report', 'ham'), ('benefits physical activity', 'ham'), ('the importance vows', 'ham')]
# [('renew your password', 'spam'), ('renew your vows', 'spam'), ('benefits of our account', 'ham'), ('the importance of physical activity', 'ham')]

# %% [markdown]
# ## Helper Functions

# %%
def np_log_fit(x, y):
    a, b = np.polyfit(np.log(x), y, 1)
    return a, b

def np_exp_fit(x, y):
    a, b = np.polyfit(x, np.log(y), 1, w=np.sqrt(y))
    return a, np.exp(b)

def plot_vocab(vocab):
    words = [word for word,_ in vocab]
    probs = [prob for _,prob in vocab]
    x_pos = np.arange(len(words)) 

    #slope, intercept = np.polyfit(x_pos, probs, 1)
    #trendline = intercept + (slope * x_pos)

    a, b = np_exp_fit(x_pos, probs)
    trendline_exp = b*np.exp(a*x_pos)

    #plt.plot(x_pos, trendline, color='red', linestyle='--')
    plt.plot(x_pos, trendline_exp, color='green', linestyle='--')
    plt.bar(x_pos, probs,align='center')
    plt.xticks(x_pos, words) 
    plt.ylabel('Probs')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %% [markdown]
# ## NB Classifier

# %%
class NB:
    def __init__(self, k=1):
        self.k = k
        self.lemmatizer = WordNetLemmatizer()
    
    def _nltk_pos_tagger(self, nltk_tag):
        if nltk_tag.startswith('J'):
            return nltk.corpus.wordnet.ADJ
        elif nltk_tag.startswith('V'):
            return nltk.corpus.wordnet.VERB
        elif nltk_tag.startswith('N'):
            return nltk.corpus.wordnet.NOUN
        elif nltk_tag.startswith('R'):
            return nltk.corpus.wordnet.ADV
        else:          
            return None
    
    def _nltk_pos_lemmatizer(self, token, tag):
        if tag is None:
            return self.lemmatizer.lemmatize(token)
        else:        
            return self.lemmatizer.lemmatize(token, tag)

    def _vocab(self, samples):
        vocab = [token for sample in samples for token in sample]
        #print(f'{samples}/{vocab}')
        return list(set(vocab))

    def _compute_likelihood(self, samples):
        likelihood = {}
        vocab = self._vocab(samples)
        
        for w in vocab:
            count = 0
            for sentence in samples:
                if w in sentence:
                    #print(w+":", sentence)
                    count += 1
            #print(f"Number of ham emails with the word '{w}': {count}")
            #prob = (count + self.k)/(len(samples) + 2.0*self.k) # smoothing
            #print(f"Probability of the word '{w}': {prob} ")
            likelihood[w.lower()] = count
        return likelihood
    
    def _p_word_spam(self, token):
        return (self.k + self.likelihood_spam.get(token, 0.0)) / ((2.0 * self.k) + self.num_spam_messages)

    def _p_word_ham(self, token):
        return (self.k + self.likelihood_ham.get(token, 0.0)) / ((2.0 * self.k) + self.num_ham_messages)

    def get_spam_vocab(self, n=10):
        vocab = []
        for k in self.likelihood_spam:
            prob = self._p_word_spam(k)
            vocab.append((k, prob))
        # Sort the vocab
        vocab.sort(reverse=True, key=lambda e: (e[1], e[0]))
        # Return
        return vocab[:min(n, len(vocab))]
    
    def get_ham_vocab(self, n=10):
        vocab = []
        for k in self.likelihood_spam:
            prob = self._p_word_ham(k)
            vocab.append((k, prob))
        # Sort the vocab
        vocab.sort(reverse=True, key=lambda e: (e[1], e[0]))
        # Return
        return vocab[:min(n, len(vocab))] 

    def train(self, dataset):
        # compute priors
        dataset_total = len(dataset)
        spam_samples = [txt for txt, label in dataset if label == 'spam']
        ham_samples = [txt for txt, label in dataset if label == 'ham']

        #print(f'{spam_samples}')
        #print(f'{ham_samples}')

        self.ps = len(spam_samples) / dataset_total
        self.ph = len(ham_samples) / dataset_total

        #print(f'{self.ps} {self.ph}')

        # Pre-process text
        ## Tokenize the text and get the POS (Part Of Speech)
        spam_samples_nltk_tagged = [nltk.pos_tag(nltk.word_tokenize(sample)) for sample in spam_samples]
        print(f'{spam_samples_nltk_tagged}')
        spam_samples = [[(t[0], self._nltk_pos_tagger(t[1])) for t in tokens] for tokens in spam_samples_nltk_tagged]
        ham_samples_nltk_tagged = [nltk.pos_tag(nltk.word_tokenize(sample)) for sample in ham_samples]
        ham_samples = [[(t[0], self._nltk_pos_tagger(t[1])) for t in tokens] for tokens in ham_samples_nltk_tagged]
        

        print(f'HAM SAMPLES {spam_samples}')

        ## Lemmatization with POS
        spam_samples = [[self._nltk_pos_lemmatizer(w,t).lower() for w,t in tokens] for tokens in spam_samples]
        ham_samples = [[self._nltk_pos_lemmatizer(w,t).lower()  for w,t in tokens] for tokens in ham_samples]
        
        #print(f'{spam_samples}')
        #print(f'{ham_samples}')

        # compute_likelihood
        self.likelihood_spam = self._compute_likelihood(spam_samples)
        self.num_spam_messages = len(spam_samples)
        self.likelihood_ham = self._compute_likelihood(ham_samples)
        self.num_ham_messages = len(ham_samples)

        #print(f'{self.likelihood_spam}')
        #print(f'{self.likelihood_ham}')
    
    def predict(self, txt):
        # Pre-process text (similar to the train)
        if txt is not None:
            tokens = nltk.word_tokenize(txt)
            tokens = [self.lemmatizer.lemmatize(w).lower() for w in tokens if len(self.lemmatizer.lemmatize(w)) > 2]
        else:
            tokens = []
        #print(tokens)

        log_p_spam = 0.0
        log_p_ham = 0.0

        for t in tokens:
            log_p_spam += math.log(self._p_word_spam(t))
            log_p_ham += math.log(self._p_word_ham(t))
        
        prob_spam = (math.exp(log_p_spam)*self.ps)/(math.exp(log_p_spam)*self.ps+math.exp(log_p_ham)*self.ph)
        if prob_spam >= 0.5:
            return 'spam', prob_spam
        else:
            return 'ham', prob_spam

# %%
clf = NB()
clf.train(dataset_train)
# Out:
# [[('send', 'VB'), ('us', 'PRP'), ('your', 'PRP$'), ('password', 'NN')], [('review', 'VB'), ('our', 'PRP$'), ('website', 'NN')], [('send', 'VB'), ('your', 'PRP$'), ('password', 'NN')], [('send', 'VB'), ('us', 'PRP'), ('your', 'PRP$'), ('account', 'NN')]]
# HAM SAMPLES [[('send', 'v'), ('us', None), ('your', None), ('password', 'n')], [('review', 'v'), ('our', None), ('website', 'n')], [('send', 'v'), ('your', None), ('password', 'n')], [('send', 'v'), ('us', None), ('your', None), ('account', 'n')]]

# %%
spam_vocab = clf.get_spam_vocab()
print(f'{spam_vocab}')

plot_vocab(spam_vocab)
# Out:
# [('your', 0.6666666666666666), ('send', 0.6666666666666666), ('u', 0.5), ('password', 0.5), ('website', 0.3333333333333333), ('review', 0.3333333333333333), ('our', 0.3333333333333333), ('account', 0.3333333333333333)]

# %%
ham_vocab = clf.get_ham_vocab()
print(f'{ham_vocab}')

plot_vocab(ham_vocab)
# Out:
# [('your', 0.4), ('website', 0.2), ('u', 0.2), ('send', 0.2), ('review', 0.2), ('password', 0.2), ('our', 0.2), ('account', 0.2)]

# %%
acc = 0.0
for sentence, label in dataset_train:
    predicted_label, prob_spam = clf.predict(sentence)
    print(f'{sentence} -> {predicted_label} {prob_spam}')
    if label == predicted_label:
        acc += 1.0
print(f'Accuracy = {acc/len(dataset_train)}')
# Out:
# send us your password -> spam 0.9487666034155597
# review our website -> spam 0.8605851979345954
# send your password -> spam 0.9487666034155597
# send us your account -> spam 0.9250693802035151
# Your activity report -> ham 0.204582651391162
# benefits physical activity -> ham 0.06041565973900433
# the importance vows -> ham 0.08796622097114705
# Accuracy = 1.0

# %%
acc = 0.0
for sentence, label in dataset_test:
    predicted_label, prob_spam = clf.predict(sentence)
    print(f'{sentence} -> {predicted_label} {prob_spam}')
    if label == predicted_label:
        acc += 1.0
print(f'Accuracy = {acc/len(dataset_test)}')
# Out:
# renew your password -> spam 0.8223684210526315
# renew your vows -> ham 0.43554006968641107
# benefits of our account -> spam 0.6067961165048542
# the importance of physical activity -> ham 0.026092764998121326
# Accuracy = 0.5

# %% [markdown]
# ## Real Dataset
#
# The SMS Spam Collection is a set of SMS tagged messages that have been collected for SMS Spam research.
# It contains one set of SMS messages in English of 5,574 messages, tagged acording being ham (legitimate) or spam.

# %%
df = pl.read_csv('../../datasets/spam.csv')
df
# Out:
# shape: (5_522, 2)
# ┌────────┬─────────────────────────────────┐
# │ Target ┆ SMS                             │
# │ ---    ┆ ---                             │
# │ str    ┆ str                             │
# ╞════════╪═════════════════════════════════╡
# │ ham    ┆ Go until jurong point, crazy..… │
# │ ham    ┆ Ok lar... Joking wif u oni...   │
# │ spam   ┆ Free entry in 2 a wkly comp to… │
# │ ham    ┆ U dun say so early hor... U c … │
# │ ham    ┆ Nah I don't think he goes to u… │
# │ …      ┆ …                               │
# │ spam   ┆ This is the 2nd time we have t… │
# │ ham    ┆ Will �_ b going to esplanade f… │
# │ ham    ┆ Pity, * was in mood for that. … │
# │ ham    ┆ The guy did some bitching but … │
# │ ham    ┆ Rofl. Its true to its name      │
# └────────┴─────────────────────────────────┘

# %%
dataset = df.rows()
dataset = [(text, label) for (label, text) in dataset]
idx = int(len(dataset)*.8)
dataset_train = dataset[0: idx]
dataset_test = dataset[idx:]

# %%
clf = NB()
clf.train(dataset_train)
# Out:
# [[('Free', 'JJ'), ('entry', 'NN'), ('in', 'IN'), ('2', 'CD'), ('a', 'DT'), ('wkly', 'JJ'), ('comp', 'NN'), ('to', 'TO'), ('win', 'VB'), ('FA', 'NNP'), ('Cup', 'NNP'), ('final', 'JJ'), ('tkts', 'NN'), ('21st', 'CD'), ('May', 'NNP'), ('2005', 'CD'), ('.', '.'), ('Text', 'VB'), ('FA', 'NNP'), ('to', 'TO'), ('87121', 'CD'), ('to', 'TO'), ('receive', 'VB'), ('entry', 'NN'), ('question', 'NN'), ('(', '('), ('std', 'JJ'), ('txt', 'NN'), ('rate', 'NN'), (')', ')'), ('T', 'NNP'), ('&', 'CC'), ('C', 'NNP'), ("'s", 'POS'), ('apply', 'VBP'), ('08452810075over18', 'CD'), ("'s", 'POS')], [('FreeMsg', 'NNP'), ('Hey', 'NNP'), ('there', 'EX'), ('darling', 'VBG'), ('it', 'PRP'), ("'s", 'VBZ'), ('been', 'VBN'), ('3', 'CD'), ('week', 'NN'), ("'s", 'POS'), ('now', 'RB'), ('and', 'CC'), ('no', 'DT'), ('word', 'NN'), ('back', 'RB'), ('!', '.'), ('I', 'PRP'), ("'d", 'MD'), ('like', 'VB'), ('some', 'DT'), ('fun', 'NN'), ('you', 'PRP'), ('up', 'IN'), ('for', 'IN'), ('it', 'PRP'), ('still', 'RB'), ('?', '.'), ('Tb', 'NNP'), ('ok', 'NN'), ('!', '.'), ('XxX', 'NNP'), ('std', 'VBD'), ('chgs', 'NN'), ('to', 'TO'), ('send', 'VB'), (',', ','), ('�1.50', 'VB'), ('to', 'TO'), ('rcv', 'VB')], [('WINNER', 'NN'), ('!', '.'), ('!', '.'), ('As', 'IN'), ('a', 'DT'), ('valued', 'VBN'), ('network', 'NN'), ('customer', 'NN'), ('you', 'PRP'), ('have', 'VBP'), ('been', 'VBN'), ('selected', 'VBN'), ('to', 'TO'), ('receivea', 'VB'), ('�900', 'NNP'), ('prize', 'VB'), ('reward', 'NN'), ('!', '.'), ('To', 'TO'), ('claim', 'VB'), ('call', 'NN'), ('09061701461', 'CD'), ('.', '.'), ('Claim', 'NNP'), ('code', 'NN'), ('KL341', 'NNP'), ('.', '.'), ('Valid', 'NNP'), ('12', 'CD'), ('hours', 'NNS'), ('only', 'RB'), ('.', '.')], [('Had', 'NNP'), ('your', 'PRP$'), ('mobile', 'JJ'), ('11', 'CD'), ('months', 'NNS'), ('or', 'CC'), ('more', 'JJR'), ('?', '.'), ('U', 'NNP'), ('R', 'NNP'), ('entitled', 'VBD'), ('to', 'TO'), ('Update', 'VB'), ('to', 'TO'), ('the', 'DT'), ('latest', 'JJS'), ('colour', 'NN'), ('mobiles', 'NNS'), ('with', 'IN'), ('camera', 'NN'), ('for', 'IN'), ('Free', 'JJ'), ('!', '.'), ('Call', 'VB'), ('The', 'DT'), ('Mobile', 'NNP'), ('Update', 'NNP'), ('Co', 'NNP'), ('FREE', 'NNP'), ('on', 'IN'), ('08002986030', 'CD')], [('SIX', 'NNP'), ('chances', 'NNS'), ('to', 'TO'), ('win', 'VB'), ('CASH', 'NNP'), ('!', '.'), ('From', 'IN'), ('100', 'CD'), ('to', 'TO'), ('20,000', 'CD'), ('pounds', 'NNS'), ('txt', 'JJ'), ('>', 'NNP'), ('CSH11', 'NNP'), ('and', 'CC'), ('send', 'VB'), ('to', 'TO'), ('87575', 'CD'), ('.', '.'), ('Cost', 'NN'), ('150p/day', 'CD'), (',', ','), ('6days', 'CD'), (',', ','), ('16+', 'CD'), ('TsandCs', 'NNP'), ('apply', 'RB'), ('Reply', 'NNP'), ('HL', 'NNP'), ('4', 'CD'), ('info', 'NN')], [('URGENT', 'NN'), ('!', '.'), ('You', 'PRP'), ('have', 'VBP'), ('won', 'VBN'), ('a', 'DT'), ('1', 'CD'), ('week', 'NN'), ('FREE', 'NNP'), ('membership', 'NN'), ('in', 'IN'), ('our', 'PRP$'), ('�100,000', 'NN'), ('Prize', 'NNP'), ('Jackpot', 'NNP'), ('!', '.'), ('Txt', 'NNP'), ('the', 'DT'), ('word', 'NN'), (':', ':'), ('CLAIM', 'NN'), ('to', 'TO'), ('No', 'DT'), (':', ':'), ('81010', 'CD'), ('T', 'NNP'), ('&', 'CC'), ('C', 'NNP'), ('www.dbuk.net', 'NN'), ('LCCLTD', 'NNP'), ('POBOX', 'NNP'), ('4403LDNW1A7RW18', 'CD')], [('XXXMobileMovieClub', 'NN'), (':', ':'), ('To', 'TO'), ('use', 'VB'), ('your', 'PRP$'), ('credit', 'NN'), (',', ','), ('click', 'VBP'), ('the', 'DT'), ('WAP', 'NNP'), ('link', 'NN'), ('in', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('txt', 'JJ'), ('message', 'NN'), ('or', 'CC'), ('click', 'NN'), ('here', 'RB'), ('>', 'NNP'), ('>', 'NNP'), ('http', 'NN'), (':', ':'), ('//wap', 'NN'), ('.', '.'), ('xxxmobilemovieclub.com', 'VB'), ('?', '.'), ('n=QJKGIGHJJGCBL', 'NN')], [('England', 'NNP'), ('v', 'NN'), ('Macedonia', 'NNP'), ('-', ':'), ('dont', 'NN'), ('miss', 'VBP'), ('the', 'DT'), ('goals/team', 'NN'), ('news', 'NN'), ('.', '.'), ('Txt', 'NNP'), ('ur', 'JJ'), ('national', 'JJ'), ('team', 'NN'), ('to', 'TO'), ('87077', 'CD'), ('eg', 'NNS'), ('ENGLAND', 'NNP'), ('to',  ...
# HAM SAMPLES [[('Free', 'a'), ('entry', 'n'), ('in', None), ('2', None), ('a', None), ('wkly', 'a'), ('comp', 'n'), ('to', None), ('win', 'v'), ('FA', 'n'), ('Cup', 'n'), ('final', 'a'), ('tkts', 'n'), ('21st', None), ('May', 'n'), ('2005', None), ('.', None), ('Text', 'v'), ('FA', 'n'), ('to', None), ('87121', None), ('to', None), ('receive', 'v'), ('entry', 'n'), ('question', 'n'), ('(', None), ('std', 'a'), ('txt', 'n'), ('rate', 'n'), (')', None), ('T', 'n'), ('&', None), ('C', 'n'), ("'s", None), ('apply', 'v'), ('08452810075over18', None), ("'s", None)], [('FreeMsg', 'n'), ('Hey', 'n'), ('there', None), ('darling', 'v'), ('it', None), ("'s", 'v'), ('been', 'v'), ('3', None), ('week', 'n'), ("'s", None), ('now', 'r'), ('and', None), ('no', None), ('word', 'n'), ('back', 'r'), ('!', None), ('I', None), ("'d", None), ('like', 'v'), ('some', None), ('fun', 'n'), ('you', None), ('up', None), ('for', None), ('it', None), ('still', 'r'), ('?', None), ('Tb', 'n'), ('ok', 'n'), ('!', None), ('XxX', 'n'), ('std', 'v'), ('chgs', 'n'), ('to', None), ('send', 'v'), (',', None), ('�1.50', 'v'), ('to', None), ('rcv', 'v')], [('WINNER', 'n'), ('!', None), ('!', None), ('As', None), ('a', None), ('valued', 'v'), ('network', 'n'), ('customer', 'n'), ('you', None), ('have', 'v'), ('been', 'v'), ('selected', 'v'), ('to', None), ('receivea', 'v'), ('�900', 'n'), ('prize', 'v'), ('reward', 'n'), ('!', None), ('To', None), ('claim', 'v'), ('call', 'n'), ('09061701461', None), ('.', None), ('Claim', 'n'), ('code', 'n'), ('KL341', 'n'), ('.', None), ('Valid', 'n'), ('12', None), ('hours', 'n'), ('only', 'r'), ('.', None)], [('Had', 'n'), ('your', None), ('mobile', 'a'), ('11', None), ('months', 'n'), ('or', None), ('more', 'a'), ('?', None), ('U', 'n'), ('R', 'n'), ('entitled', 'v'), ('to', None), ('Update', 'v'), ('to', None), ('the', None), ('latest', 'a'), ('colour', 'n'), ('mobiles', 'n'), ('with', None), ('camera', 'n'), ('for', None), ('Free', 'a'), ('!', None), ('Call', 'v'), ('The', None), ('Mobile', 'n'), ('Update', 'n'), ('Co', 'n'), ('FREE', 'n'), ('on', None), ('08002986030', None)], [('SIX', 'n'), ('chances', 'n'), ('to', None), ('win', 'v'), ('CASH', 'n'), ('!', None), ('From', None), ('100', None), ('to', None), ('20,000', None), ('pounds', 'n'), ('txt', 'a'), ('>', 'n'), ('CSH11', 'n'), ('and', None), ('send', 'v'), ('to', None), ('87575', None), ('.', None), ('Cost', 'n'), ('150p/day', None), (',', None), ('6days', None), (',', None), ('16+', None), ('TsandCs', 'n'), ('apply', 'r'), ('Reply', 'n'), ('HL', 'n'), ('4', None), ('info', 'n')], [('URGENT', 'n'), ('!', None), ('You', None), ('have', 'v'), ('won', 'v'), ('a', None), ('1', None), ('week', 'n'), ('FREE', 'n'), ('membership', 'n'), ('in', None), ('our', None), ('�100,000', 'n'), ('Prize', 'n'), ('Jackpot', 'n'), ('!', None), ('Txt', 'n'), ('the', None), ('word', 'n'), (':', None), ('CLAIM', 'n'), ('to', None), ('No', None), (':', None), ('81010', None), ('T', 'n'), ('&', None), ('C', 'n'), ('www.dbuk.net', 'n'), ('LCCLTD', 'n'), ('POBOX', 'n'), ('4403LDNW1A7RW18', None)], [('XXXMobileMovieClub', 'n'), (':', None), ('To', None), ('use', 'v'), ('your', None), ('credit', 'n'), (',', None), ('click', 'v'), ('the', None), ('WAP', 'n'), ('link', 'n'), ('in', None), ('the', None), ('next', 'a'), ('txt', 'a'), ('message', 'n'), ('or', None), ('click', 'n'), ('here', 'r'), ('>', 'n'), ('>', 'n'), ('http', 'n'), (':', None), ('//wap', 'n'), ('.', None), ('xxxmobilemovieclub.com', 'v'), ('?', None), ('n=QJKGIGHJJGCBL', 'n')], [('England', 'n'), ('v', 'n'), ('Macedonia', 'n'), ('-', None), ('dont', 'n'), ('miss', 'v'), ('the', None), ('goals/team', 'n'), ('news', 'n'), ('.', None), ('Txt', 'n'), ('ur', 'a'), ('national', 'a'), ('team', 'n'), ('to', None), ('87077', None), ('eg', 'n'), ('ENGLAND', 'n'), ('to', None), ('87077', None), ('Try', 'n'), (':', None), ('WALES', 'n'), (',', None), ('SCOTLAND', 'n'), ('4txt/̼1.20', None), ('POBOXox36504W45WQ', 'n'), ('16+', None)], [('Thanks', ' ...

# %%
spam_vocab = clf.get_spam_vocab(30)
print(f'{spam_vocab}')

plot_vocab(spam_vocab)
# Out:
# [('.', 0.6783333333333333), ('to', 0.6216666666666667), ('!', 0.48833333333333334), ('call', 0.43), ('a', 0.4083333333333333), ('be', 0.3883333333333333), ('you', 0.32166666666666666), (',', 0.30833333333333335), ('your', 0.2833333333333333), ('now', 0.2733333333333333), ('or', 0.23166666666666666), ('free', 0.225), ('for', 0.225), ('the', 0.22), ('have', 0.21), ('txt', 0.20833333333333334), ('&', 0.195), ('2', 0.18833333333333332), ('?', 0.175), (':', 0.17166666666666666), ('u', 0.17), ('on', 0.16666666666666666), ('and', 0.165), ('ur', 0.16333333333333333), ('text', 0.16333333333333333), ('from', 0.16166666666666665), ('4', 0.15333333333333332), ('claim', 0.14666666666666667), ('mobile', 0.14333333333333334), ('win', 0.14166666666666666)]

# %%
ham_vocab = clf.get_ham_vocab(30)
print(f'{ham_vocab}')

plot_vocab(ham_vocab)
# Out:
# [('.', 0.4340314136125654), ('i', 0.41413612565445024), ('be', 0.29790575916230366), ('you', 0.28534031413612565), ('to', 0.2554973821989529), ('?', 0.2319371727748691), (',', 0.22015706806282723), ('a', 0.19581151832460733), ('the', 0.17853403141361257), ('in', 0.15209424083769635), ('u', 0.15157068062827225), ('...', 0.14528795811518325), ('and', 0.1450261780104712), ('me', 0.14031413612565444), ('it', 0.13455497382198953), ('do', 0.13141361256544504), ('my', 0.12303664921465969), ('have', 0.1212041884816754), ('!', 0.11465968586387434), ('get', 0.112565445026178), ('that', 0.10130890052356022), ('go', 0.09633507853403141), ('of', 0.09528795811518324), ('for', 0.09293193717277487), ('..', 0.09083769633507853), ('but', 0.08376963350785341), (':', 0.08298429319371728), ('not', 0.08219895287958115), ('so', 0.08141361256544502), ("'s", 0.07879581151832461)]

# %%
acc = 0.0
for sentence, label in dataset_train:
    predicted_label, prob_spam = clf.predict(sentence)
    #print(f'{sentence} -> {predicted_label} {prob_spam}')
    if label == predicted_label:
        acc += 1.0
print(f'Accuracy = {acc/len(dataset_train)}')
# Out:
# Accuracy = 0.7842426986642518

# %%
acc = 0.0
for sentence, label in dataset_test:
    predicted_label, prob_spam = clf.predict(sentence)
    #print(f'{sentence} -> {predicted_label} {prob_spam}')
    if label == predicted_label:
        acc += 1.0
print(f'Accuracy = {acc/len(dataset_test)}')
# Out:
# Accuracy = 0.7104072398190046
